# %%
import pandas as pd

# %%
data = pd.read_csv('genz_labeled_dataset.csv')
data.head(10)
# Out:
#    index     type    subreddit  \
# 0      0  comment  youngadults
# 1      1  comment         GenZ
# 2      2  comment  youngadults
# 3      3  comment  youngadults
# 4      4  comment       school
# 5      5  comment      college
# 6      6  comment      college
# 7      7  comment         GenZ
# 8      8  comment         GenZ
# 9      9  comment       school
#
#                                              content  score  risk_score  \
# 0  Because they are protesting the exorbitant pri...      1           1
# 1  Racism is at the very heart of many political ...      5           0
# 2  Theres no such thing as an adult job. A job is...      5           0
# 3                       i'm already a resident there      3           0
# 4  My 8th graders school fees are $0, but I need ...      0           1
# 5  Reading this was kinda funny because I have a ...      2           0
# 6  Social Security Card and/or passport are often...      2           0
# ...

# %%
sum(data['gpt_classification'] == 'HARMFUL')
# Out:
# 139
